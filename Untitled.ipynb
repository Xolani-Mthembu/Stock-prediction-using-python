# %%
#import the packages "Pandas" and "MatPlotLib" into Jupyter Notebook
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import Facebook's stock data
fb = pd.DataFrame.from_csv('../data/facebook.csv')

# %%
print(fb.head())
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200

# %%
fb.shape
# Out:
# (780, 6)

# %%
fb.plot()

# %%
fb.plot(title='Facebook data', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f23270a7940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f2327054390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f23248b4470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f2324827fd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f23220b4940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f23220b4978>], dtype=object)

# %%
# calculate daily stock_data returns
stock_returns = fb.pct_change()

# plot the daily returns
stock_returns.plot()


# summarize the daily returns
stock_returns.describe()
# Out:
#              Open        High         Low       Close   Adj Close      Volume
# count  779.000000  779.000000  779.000000  779.000000  779.000000  779.000000
# mean     0.003385    0.003375    0.003257    0.003362    0.003401    0.082891
# std      0.023974    0.022760    0.023086    0.025850    0.025851    0.471923
# min     -0.122910   -0.099703   -0.113207   -0.092723   -0.092723   -0.610288
# 25%     -0.008351   -0.006797   -0.007727   -0.008059   -0.007678   -0.210153
# 50%      0.002700    0.001714    0.003309    0.002504    0.002504   -0.030077
# 75%      0.016001    0.011576    0.014320    0.013861    0.013861    0.229165
# max      0.112184    0.241538    0.175854    0.298067    0.298067    2.761598

# %%
#Opening and closing price
plt.figure(figsize=(10, 8))
fb['Open'].plot()
plt.show()

# %%
#Opening and closing price
plt.figure(figsize=(10, 8))
fb['Close'].plot()
plt.show()
